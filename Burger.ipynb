# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
import glob
import re
from datetime import datetime

data = pd.read_csv('food_fb.csv')
data['As Of Date'] = pd.to_datetime(data['As Of Date'], format = "%m/%d/%Y %H:%M")

# %%
data
# Out:
#      Ticker Symbol   Entity Name  Unique ID As Of Date         Username  \
# 0      nasdaq:jack  4.689535e+10   38467057 2018-06-25     jackinthebox
# 1         nyse:mcd  5.024557e+10   38467785 2018-06-25      McDonaldsUS
# 2         nyse:mcd  4.842321e+10   38467784 2018-06-25       rmhcglobal
# 3       nasdaq:wen  1.133850e+11   38467320 2018-06-25           wendys
# 4      nasdaq:sonc  2.454096e+10   38466059 2018-06-25     sonicdrivein
# 5         nyse:mcd  1.015010e+16   38462907 2018-06-15        McDonalds
# 6         nyse:qsr  1.346150e+14   38463225 2018-06-14       burgerking
# 7         nyse:mcd  1.434420e+15   38462908 2018-06-14  McDonaldsLatino
# 8         nyse:qsr  2.353590e+14   38463226 2018-06-14     TimHortonsUS
# 9         nyse:mcd  4.842321e+10   38458713 2018-06-13       rmhcglobal
# 10     nasdaq:sonc  2.454096e+10   38457639 2018-06-13     sonicdrivein
# 11      nasdaq:wen  1.133850e+11   38457768 2018-06-13           wendys
# 12        nyse:mcd  5.024557e+10   38458714 2018-06-13      McDonaldsUS
# 13     nasdaq:jack  4.689535e+10   38457229 2018-06-13     jackinthebox
# 14        nyse:mcd  1.434420e+15   38456009 2018-06-09  McDonaldsLatino
# 15        nyse:mcd  1.015010e+16   38456008 2018-06-09        McDonalds
# 16        nyse:mcd  5.024557e+10   38450911 2018-06-08      McDonaldsUS
# 17      nasdaq:wen  1.133850e+11   38449408 2018-06-08           wendys
# 18     nasdaq:sonc  2.454096e+10   38449199 2018-06-08     sonicdrivein
# 19     nasdaq:jack  4.689535e+10   38448543 2018-06-08     jackinthebox
# 20        nyse:qsr  1.346150e+14   38451521 2018-06-08       burgerking
# 21        nyse:mcd  4.842321e+10   38450910 2018-06-08       rmhcglobal
# 22        nyse:qsr  2.353590e+14   38451522 2018-06-08     TimHortonsUS
# 23        nyse:qsr  2.353590e+14   38444917 2018-06-07     TimHortonsUS
# 24        nyse:mcd  1.434420e+15   38444584 2018-06-07  McDonaldsLatino
# 25        nyse:mcd  1.015010e+16   38444583 2018-06-07        McDonalds
# 26        nyse:mcd  4.842321e+10   38440392 2018-06-06       rmhcglobal
# 27        nyse:qsr  1.346150e+14   38444916 2018-06-06       burgerking
# 28        nyse:mcd  5.024557e+10   38440393 2018-06-06      McDonaldsUS
# 29     nasdaq:sonc  2.454096e+10   38439364 2018-06-06     sonicdrivein
# ...            ...           ...        ...        ...              ...
# 8559   nasdaq:jack  4.689535e+10      24857 2015-01-18     jackinthebox
# 8560      nyse:qsr  1.346150e+14      81409 2015-01-18       burgerking
# 8561      nyse:qsr  1.346150e+14      81408 2015-01-17       burgerking
# 8562   nasdaq:jack  4.689535e+10      24856 2015-01-17     jackinthebox
# 8563   nasdaq:jack  4.689535e+10      24855 2015-01-16     jackinthebox
# 8564      nyse:qsr  1.346150e+14      81407 2015-01-16       burgerking
# 8565   nasdaq:jack  4.689535e+10      24854 2015-01-15     jackinthebox
# 50%    4.334136e+06         13809.000000  1.133850e+11
# 75%    8.426978e+06         47653.000000  2.353590e+14
# max    7.781078e+07        869485.000000  1.015010e+16

# %%
data['Ticker Symbol'].unique()
# Out:
# array(['nasdaq:jack', 'nyse:mcd', 'nasdaq:wen', 'nasdaq:sonc', 'nyse:qsr'], dtype=object)

# %%
data['Username'].unique()
# Out:
# array(['jackinthebox', 'McDonaldsUS', 'rmhcglobal', 'wendys',
#        'sonicdrivein', 'McDonalds', 'burgerking', 'McDonaldsLatino',
#        'TimHortonsUS'], dtype=object)

# %% [markdown]
# Tickers and associated Usernames:
# * 'nasdaq:jack' - Jack in the Box (jackinthebox)
# * 'nyse:mcd' - McDonalds (McDonaldsUS, McDonalds, McDonaldsLatino, rmhcglobal)
# * 'nasdaq:wen' - Wendys (wendys)
# * 'nasdaq:sonc' - Sonic Corp. (sonicdrivein)
# * 'nyse:qsr' - Restaurant Group (burgerking, TimHortonsUS)
#
# Were Here Count: cumulative
#
# Likes: cumulative
#
# Talking About Count: additive

# %% [markdown]
# # Likes Over Time

# %%
import matplotlib.pyplot as plt
import numpy as np
fig1, f1_axes = plt.subplots(ncols=2, nrows=4,figsize=(18,18))
fig1.suptitle('Facebook Likes Over Time')

plt.subplot(4, 2, 1)
plt.title('Jack in the Box')
df_jack = data[data['Username']=='jackinthebox']
plt.plot(df_jack['As Of Date'],df_jack['Likes'])

plt.subplot(4, 2, 2)
plt.title('Wendys')
df_wendys = data[data['Username']=='wendys']
plt.plot(df_wendys['As Of Date'],df_wendys['Likes'])

plt.subplot(4, 2, 3)
plt.title('McDonalds US')
df_mcd_us = data[data['Username']=='McDonaldsUS']
plt.plot(df_mcd_us['As Of Date'],df_mcd_us['Likes'])

plt.subplot(4, 2, 4)
plt.title('McDonalds Latino')
df_mcd_lat = data[data['Username']=='McDonaldsLatino']
plt.plot(df_mcd_lat['As Of Date'],df_mcd_lat['Likes'])

plt.subplot(4, 2, 5)
plt.title('Sonic')
df_sonic = data[data['Username']=='sonicdrivein']
plt.plot(df_sonic['As Of Date'],df_sonic['Likes'])

plt.subplot(4, 2, 6)
plt.title('Burger King')
df_bk = data[data['Username']=='burgerking']
plt.plot(df_bk['As Of Date'],df_bk['Likes'])

plt.subplot(4, 2, 7)
plt.title('Tim Hortons US')
df_tim = data[data['Username']=='TimHortonsUS']
plt.plot(df_tim['As Of Date'],df_tim['Likes'])

plt.show()

# %%
fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_xlabel('Time (months)')
ax1.set_ylabel('Jack in the Box', color=color)
df_jack = data[data['Username']=='jackinthebox']
df_jack = df_jack[df_jack['As Of Date'] >= '2016-12']
ax1.plot(df_jack['As Of Date'],df_jack['Likes'], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('Wendys', color=color)  # we already handled the x-label with ax1
df_wendys = df_wendys[df_wendys['As Of Date'] >= '2016-12']
ax2.plot(df_wendys['As Of Date'],df_wendys['Likes'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  # otherwise the right y-label is slightly clipped


fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_xlabel('Time (months)')
ax1.set_ylabel('Jack in the Box', color=color)
df_jack = data[data['Username']=='jackinthebox']
df_jack = df_jack[df_jack['As Of Date'] >= '2015-12']
ax1.plot(df_jack['As Of Date'],df_jack['Likes'], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('McDonalds US', color=color)  # we already handled the x-label with ax1
df_mcd_us = df_mcd_us[df_mcd_us['As Of Date'] >= '2015-12']
ax2.plot(df_mcd_us['As Of Date'],df_mcd_us['Likes'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_xlabel('Time (months)')
ax1.set_ylabel('Jack in the Box', color=color)
df_jack = data[data['Username']=='jackinthebox']
df_jack = df_jack[df_jack['As Of Date'] >= '2015-12']
ax1.plot(df_jack['As Of Date'],df_jack['Likes'], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('McDonalds Latino', color=color)  # we already handled the x-label with ax1
df_mcd_lat = df_mcd_lat[df_mcd_lat['As Of Date'] >= '2015-12']
ax2.plot(df_mcd_lat['As Of Date'],df_mcd_lat['Likes'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_xlabel('Time (months)')
ax1.set_ylabel('Jack in the Box', color=color)
df_jack = data[data['Username']=='jackinthebox']
df_jack = df_jack[df_jack['As Of Date'] >= '2015-12']
ax1.plot(df_jack['As Of Date'],df_jack['Likes'], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('Sonic', color=color)  # we already handled the x-label with ax1
df_sonic = df_sonic[df_sonic['As Of Date'] >= '2015-12']
ax2.plot(df_sonic['As Of Date'],df_sonic['Likes'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_xlabel('Time (months)')
ax1.set_ylabel('Jack in the Box', color=color)
df_jack = data[data['Username']=='jackinthebox']
df_jack = df_jack[df_jack['As Of Date'] >= '2015-12']
ax1.plot(df_jack['As Of Date'],df_jack['Likes'], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('Burger King', color=color)  # we already handled the x-label with ax1
df_bk = df_bk[df_bk['As Of Date'] >= '2015-12']
ax2.plot(df_bk['As Of Date'],df_bk['Likes'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_xlabel('Time (months)')
ax1.set_ylabel('Jack in the Box', color=color)
df_jack = data[data['Username']=='jackinthebox']
df_jack = df_jack[df_jack['As Of Date'] >= '2016-06']
ax1.plot(df_jack['As Of Date'],df_jack['Likes'], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('Tim Hortons US', color=color)  # we already handled the x-label with ax1
df_tim = df_tim[df_tim['As Of Date'] >= '2016-06']
ax2.plot(df_tim['As Of Date'],df_tim['Likes'], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
df_jack = data[data['Username']=='jackinthebox']
df_jack = df_jack[df_jack['As Of Date'] > '2016-12']
df_jack
# Out:
#      Ticker Symbol   Entity Name  Unique ID As Of Date      Username  \
# 0      nasdaq:jack  4.689535e+10   38467057 2018-06-25  jackinthebox
# 13     nasdaq:jack  4.689535e+10   38457229 2018-06-13  jackinthebox
# 19     nasdaq:jack  4.689535e+10   38448543 2018-06-08  jackinthebox
# 31     nasdaq:jack  4.689535e+10   38438965 2018-06-06  jackinthebox
# 42     nasdaq:jack  4.689535e+10   38427996 2018-06-03  jackinthebox
# 46     nasdaq:jack  4.689535e+10   38415222 2018-06-01  jackinthebox
# 58     nasdaq:jack  4.689535e+10   38412494 2018-05-31  jackinthebox
# 62     nasdaq:jack  4.689535e+10   37410516 2018-05-29  jackinthebox
# 75     nasdaq:jack  4.689535e+10   37410515 2018-05-28  jackinthebox
# 85     nasdaq:jack  4.689535e+10   37400353 2018-05-27  jackinthebox
# 87     nasdaq:jack  4.689535e+10   37397937 2018-05-26  jackinthebox
# 95     nasdaq:jack  4.689535e+10   37389108 2018-05-25  jackinthebox
# 101    nasdaq:jack  4.689535e+10   36613853 2018-05-23  jackinthebox
# 113    nasdaq:jack  4.689535e+10   36604768 2018-05-22  jackinthebox
# 113   Travel & Leisure
# 124   Travel & Leisure
# 135   Travel & Leisure
# 145   Travel & Leisure
# 148   Travel & Leisure
# 161   Travel & Leisure
# 171   Travel & Leisure
# 176   Travel & Leisure
# 190   Travel & Leisure
# 194   Travel & Leisure
# 206   Travel & Leisure
# 210   Travel & Leisure
# 220   Travel & Leisure
# 228   Travel & Leisure
# 242   Travel & Leisure
# 251   Travel & Leisure
# 257   Travel & Leisure
# ...                ...
# 4631  Travel & Leisure
# 4641  Travel & Leisure
# 4648  Travel & Leisure
# 4661  Travel & Leisure
# 4667  Travel & Leisure
# 4675  Travel & Leisure
# 4682  Travel & Leisure
# 4691  Travel & Leisure
# 4707  Travel & Leisure
# 4709  Travel & Leisure
# 4718  Travel & Leisure
# 4728  Travel & Leisure
# 4736  Travel & Leisure
# 4749  Travel & Leisure
# 4760  Travel & Leisure
# 4765  Travel & Leisure
# 4773  Travel & Leisure
# 4789  Travel & Leisure
# 4791  Travel & Leisure
# 4804  Travel & Leisure
# 4808  Travel & Leisure
# 4821  Travel & Leisure
# 4830  Travel & Leisure
# 4836  Travel & Leisure
# 4849  Travel & Leisure
# 4860  Travel & Leisure
# 4870  Travel & Leisure
# 4872  Travel & Leisure
# 4880  Travel & Leisure
# 4894  Travel & Leisure
#
# [545 rows x 15 columns]

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
#ax1.set_xlabel('time (s)')
ax1.set_ylabel('Jack in the Box', color=color)
df_jack = data[data['Username']=='jackinthebox']
#df_jack = data[data['As Of Date'] > '2016-12']
ax1.plot(df_jack['As Of Date'],df_jack['Likes'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Wendys', color=color)  # we already handled the x-label with ax1
ax2.plot(df_wendys['As Of Date'],df_wendys['Likes'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

plt.show()

# %% [markdown]
# # Were Here Count

# %%
fig1, f1_axes = plt.subplots(ncols=2, nrows=4,figsize=(18,18))
fig1.suptitle("Facebook 'Were Here Count' Over Time")

plt.subplot(4, 2, 1)
plt.title('Jack in the Box')
df_jack = data[data['Username']=='jackinthebox']
plt.plot(df_jack['As Of Date'],df_jack['Were Here Count'])

plt.subplot(4, 2, 2)
plt.title('Wendys')
df_wendys = data[data['Username']=='wendys']
plt.plot(df_wendys['As Of Date'],df_wendys['Were Here Count'])

plt.subplot(4, 2, 3)
plt.title('McDonalds US')
df_mcd_us = data[data['Username']=='McDonaldsUS']
plt.plot(df_mcd_us['As Of Date'],df_mcd_us['Were Here Count'])

plt.subplot(4, 2, 4)
plt.title('McDonalds Latino')
df_mcd_lat = data[data['Username']=='McDonaldsLatino']
plt.plot(df_mcd_lat['As Of Date'],df_mcd_lat['Were Here Count'])

plt.subplot(4, 2, 5)
plt.title('Sonic')
df_sonic = data[data['Username']=='sonicdrivein']
plt.plot(df_sonic['As Of Date'],df_sonic['Were Here Count'])

plt.subplot(4, 2, 6)
plt.title('Burger King')
df_bk = data[data['Username']=='burgerking']
plt.plot(df_bk['As Of Date'],df_bk['Were Here Count'])

plt.subplot(4, 2, 7)
plt.title('Tim Hortons US')
df_tim = data[data['Username']=='TimHortonsUS']
plt.plot(df_tim['As Of Date'],df_tim['Were Here Count'])

plt.show()
